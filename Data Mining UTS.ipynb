# %%
  #import libraly pandas, seaborn, matplotlib
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

path ="https://raw.githubusercontent.com/Moonrack/uts/main/loan_data.csv"

# %%
pd.set_option( 'display.max_columns' , None )

# %%
#review data dari link path
df=pd.read_csv(path)
df.head(100)
# Out:
#      Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0   LP001003   Male     Yes          1      Graduate            No
# 1   LP001005   Male     Yes          0      Graduate           Yes
# 2   LP001006   Male     Yes          0  Not Graduate            No
# 3   LP001008   Male      No          0      Graduate            No
# 4   LP001013   Male     Yes          0  Not Graduate            No
# ..       ...    ...     ...        ...           ...           ...
# 95  LP001535   Male      No          0      Graduate            No
# 96  LP001546   Male      No          0      Graduate           NaN
# 97  LP001560   Male     Yes          0  Not Graduate            No
# 98  LP001565   Male     Yes          1      Graduate            No
# 99  LP001572   Male     Yes          0      Graduate            No
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              4583             1508.0       128.0             360.0
# ...

# %%
#cek duplikasi data
df.duplicated().sum()
# Out:
# 0

# %%
#Mendroop / menghapus Columns Loan_ID
df.drop(columns=['Loan_ID'],inplace=True)
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male     Yes          1      Graduate            No             4583
# 1   Male     Yes          0      Graduate           Yes             3000
# 2   Male     Yes          0  Not Graduate            No             2583
# 3   Male      No          0      Graduate            No             6000
# 4   Male     Yes          0  Not Graduate            No             2333
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0             1508.0       128.0             360.0             1.0
# 1                0.0        66.0             360.0             1.0
# 2             2358.0       120.0             360.0             1.0
# 3                0.0       141.0             360.0             1.0
# 4             1516.0        95.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Rural           N
# 1         Urban           Y
# 2         Urban           Y
# ...

# %%
#mengechek data kosong
df.isna()
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0     False    False       False      False          False            False
# 1     False    False       False      False          False            False
# 2     False    False       False      False          False            False
# 3     False    False       False      False          False            False
# 4     False    False       False      False          False            False
# ..      ...      ...         ...        ...            ...              ...
# 376   False    False       False      False          False            False
# 377   False    False       False      False          False            False
# 378   False    False       False      False          False            False
# 379   False    False       False      False          False            False
# 380   False    False       False      False          False            False
#
# ...

# %%
#cek berapa data kosong yang ada di columns
df.isna().sum()
# Out:
# Gender                5
# Married               0
# Dependents            8
# Education             0
# Self_Employed        21
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     11
# Credit_History       30
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
baris,kolom= df.shape
print (f'jumlah data ada {baris} record, jumlah fitur ada: {kolom} kolom')
# Out:
# jumlah data ada 381 record, jumlah fitur ada: 12 kolom

# %%
#menghapus kolom data yang paling bangak kosongnya
df.drop(columns=['Credit_History'], inplace=True)
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male     Yes          1      Graduate            No             4583
# 1   Male     Yes          0      Graduate           Yes             3000
# 2   Male     Yes          0  Not Graduate            No             2583
# 3   Male      No          0      Graduate            No             6000
# 4   Male     Yes          0  Not Graduate            No             2333
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term Property_Area Loan_Status
# 0             1508.0       128.0             360.0         Rural           N
# 1                0.0        66.0             360.0         Urban           Y
# 2             2358.0       120.0             360.0         Urban           Y
# 3                0.0       141.0             360.0         Urban           Y
# 4             1516.0        95.0             360.0         Urban           Y

# %%
#menampilkan sample data berjumlah 10 dengan no acak secara random
df.sample(10)
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 166  Female      No          0      Graduate           NaN             3418
# 348    Male     Yes          0      Graduate            No             2785
# 341  Female      No          0      Graduate            No             2138
# 257  Female      No          0  Not Graduate            No             1963
# 3      Male      No          0      Graduate            No             6000
# 205    Male     Yes         3+      Graduate            No             4342
# 197    Male      No          0  Not Graduate            No             2927
# 221  Female     Yes          0      Graduate            No             2423
# 311    Male      No          0  Not Graduate            No             3691
# 200    Male     Yes          1  Not Graduate            No             3399
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term Property_Area Loan_Status
# ...

# %%
df[df.Loan_Amount_Term.isna()]
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 13     Male     Yes          0      Graduate           NaN             2600
# 24     Male     Yes          0      Graduate            No             1828
# 31     Male     Yes          0  Not Graduate           Yes             4695
# 32   Female      No          0      Graduate            No             3410
# 53     Male     Yes         3+  Not Graduate            No             4755
# 118  Female      No          0  Not Graduate            No             1907
# 143    Male      No          0  Not Graduate            No             3189
# 213    Male     Yes        NaN      Graduate           Yes             5503
# 231    Male      No          0      Graduate            No             5124
# 267  Female      No          0  Not Graduate            No             2720
# 269    Male     Yes          1      Graduate            No             7250
#
# ...

# %%
df.Loan_Amount_Term.mean()
# Out:
# 340.86486486486484

# %%
df.Loan_Amount_Term.median()
# Out:
# 360.0

# %%
df.Loan_Amount_Term.mode()
# Out:
# 0    360.0
# Name: Loan_Amount_Term, dtype: float64

# %%
#pengisian terhadap nilai kosong dengan nilai rata-rata (mean) di kolum Loan_Amount_Term
df.Loan_Amount_Term.fillna(df.Loan_Amount_Term.mean(), inplace=True)
df.isna().sum()
# Out:
# Gender                5
# Married               0
# Dependents            8
# Education             0
# Self_Employed        21
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.iloc[[7]]
# Out:
#   Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# 7   Male      No          0  Graduate            No             1853
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term Property_Area Loan_Status
# 7             2840.0       114.0             360.0         Rural           N

# %%
#melihat data yang terbanyak pada kategori yang telah dideklarasikan
df.Loan_Status.value_counts()
# Out:
# Loan_Status
# Y    271
# N    110
# Name: count, dtype: int64

# %%
df[df.Loan_Status.isna()]
# Out:
# Empty DataFrame
# Columns: [Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Property_Area, Loan_Status]
# Index: []

# %%
#Mengisi data kategori dengan data terbanyak
df.Self_Employed.fillna('S', inplace=True)
df.isna().sum()
# Out:
# Gender               5
# Married              0
# Dependents           8
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df.iloc[[18,121]]
# Out:
#     Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 18    Male     Yes          2  Not Graduate            No             4226
# 121   Male     Yes          1  Not Graduate            No             3500
#
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term Property_Area Loan_Status
# 18              1040.0       110.0             360.0         Urban           Y
# 121             1083.0       135.0             360.0         Urban           Y

# %%
#Splitting numerical dan categorical data type
df.describe(include='all')
# Out:
#        Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# count     376     381        373       381           381       381.000000
# unique      2       2          4         2             3              NaN
# top      Male     Yes          0  Graduate            No              NaN
# freq      291     228        234       278           325              NaN
# mean      NaN     NaN        NaN       NaN           NaN      3579.845144
# std       NaN     NaN        NaN       NaN           NaN      1419.813818
# min       NaN     NaN        NaN       NaN           NaN       150.000000
# 25%       NaN     NaN        NaN       NaN           NaN      2600.000000
# 50%       NaN     NaN        NaN       NaN           NaN      3333.000000
# 75%       NaN     NaN        NaN       NaN           NaN      4288.000000
# max       NaN     NaN        NaN       NaN           NaN      9703.000000
#
#         CoapplicantIncome  LoanAmount  Loan_Amount_Term Property_Area  \
# ...

# %%
numerical_cols=['ApplicantIncome','LoanAmount','Gender','CoapplicantIncome']
categorical_cols=['Education','Property_Area']

# %%
sns.displot(data= df, x= 'Education',bins=20, kde=True)

# %%
#Menampilkan data numerical kolom
fig,axs=plt.subplots(2,2, figsize=(16,8))
for col,ax in zip(numerical_cols,axs.flatten()):
  ax.set_title(col)
  sns.histplot(data= df, x= col,bins=20,kde=True, ax=ax)

plt.tight_layout()

# %%
#Menampilkan data yang sudah menikah dan yang tidak menikah
sns.countplot(data= df, x= 'Married')
# Out:
# <Axes: xlabel='Married', ylabel='count'>
